# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv(r"C:\Users\Gayatri Varma\Desktop\dup.csv",encoding="ISO-8859-1")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dataset
# Out:
#              dateCrawled  seller offerType  postalCode           brand  \
# 0       24-03-2016 11:52  privat   Angebot     70435.0      volkswagen
# 1       24-03-2016 10:58  privat   Angebot     66954.0            audi
# 2       14-03-2016 12:52  privat   Angebot     90480.0            jeep
# 3       17-03-2016 16:54  privat   Angebot     91074.0      volkswagen
# 4       31-03-2016 17:25  privat   Angebot     60437.0           skoda
# 5       04-04-2016 17:36  privat   Angebot     33775.0             bmw
# 6       01-04-2016 20:48  privat   Angebot     67112.0         peugeot
# 7       21-03-2016 18:54  privat   Angebot     19348.0      volkswagen
# 8       04-04-2016 23:42  privat   Angebot     94505.0            ford
# 9       17-03-2016 10:53  privat   Angebot     27472.0      volkswagen
# 10      26-03-2016 19:54  privat   Angebot     96224.0           mazda
# 11      07-04-2016 10:06  privat   Angebot     57290.0      volkswagen
# ...

# %%
dataset.isnull().any()
# Out:
# dateCrawled            True
# seller                 True
# offerType              True
# postalCode             True
# brand                  True
# dateCreated            True
# model                  True
# lastSeen               True
# nrOfPictures           True
# name                   True
# vehicleType            True
# abtest                 True
# carage                 True
# gearbox                True
# powerPS                True
# kilometer              True
# monthOfRegistration    True
# fuelType               True
# notRepairedDamage      True
# price                  True
# dtype: bool

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#              dateCrawled  seller offerType  postalCode          brand  \
# 3       17-03-2016 16:54  privat   Angebot     91074.0     volkswagen
# 4       31-03-2016 17:25  privat   Angebot     60437.0          skoda
# 5       04-04-2016 17:36  privat   Angebot     33775.0            bmw
# 6       01-04-2016 20:48  privat   Angebot     67112.0        peugeot
# 7       21-03-2016 18:54  privat   Angebot     19348.0     volkswagen
# 10      26-03-2016 19:54  privat   Angebot     96224.0          mazda
# 11      07-04-2016 10:06  privat   Angebot     57290.0     volkswagen
# 14      21-03-2016 12:57  privat   Angebot      4177.0         nissan
# 17      20-03-2016 10:25  privat   Angebot     65599.0        renault
# 18      23-03-2016 15:48  privat   Angebot     88361.0           ford
# 19      01-04-2016 22:55  privat   Angebot     49565.0  mercedes_benz
# 20      01-04-2016 19:56  privat   Angebot     75365.0     volkswagen
# ...

# %%
dataset.isnull().any()
# Out:
# dateCrawled            False
# seller                 False
# offerType              False
# postalCode             False
# brand                  False
# dateCreated            False
# model                  False
# lastSeen               False
# nrOfPictures           False
# name                   False
# vehicleType            False
# abtest                 False
# carage                 False
# gearbox                False
# powerPS                False
# kilometer              False
# monthOfRegistration    False
# fuelType               False
# notRepairedDamage      False
# price                  False
# dtype: bool

# %%
dataset
# Out:
#              dateCrawled  seller offerType  postalCode          brand  \
# 3       17-03-2016 16:54  privat   Angebot     91074.0     volkswagen
# 4       31-03-2016 17:25  privat   Angebot     60437.0          skoda
# 5       04-04-2016 17:36  privat   Angebot     33775.0            bmw
# 6       01-04-2016 20:48  privat   Angebot     67112.0        peugeot
# 7       21-03-2016 18:54  privat   Angebot     19348.0     volkswagen
# 10      26-03-2016 19:54  privat   Angebot     96224.0          mazda
# 11      07-04-2016 10:06  privat   Angebot     57290.0     volkswagen
# 14      21-03-2016 12:57  privat   Angebot      4177.0         nissan
# 17      20-03-2016 10:25  privat   Angebot     65599.0        renault
# 18      23-03-2016 15:48  privat   Angebot     88361.0           ford
# 19      01-04-2016 22:55  privat   Angebot     49565.0  mercedes_benz
# 20      01-04-2016 19:56  privat   Angebot     75365.0     volkswagen
# ...

# %%
x=dataset.iloc[:,10:19].values

# %%
x
# Out:
# array([['kleinwagen', 'test', 18.0, ..., 6, 'benzin', 'nein'],
#        ['kleinwagen', 'test', 11.0, ..., 7, 'diesel', 'nein'],
#        ['limousine', 'test', 24.0, ..., 10, 'benzin', 'ja'],
#        ...,
#        ['bus', 'control', 19.0, ..., '3', 'benzin', 'nein'],
#        ['cabrio', 'test', 19.0, ..., '3', 'benzin', 'nein'],
#        ['bus', 'test', 23.0, ..., '3', 'diesel', 'nein']], dtype=object)

# %%
x.shape
# Out:
# (260964, 9)

# %%
y=dataset.iloc[:,19:20].values

# %%
y
# Out:
# array([[1500.],
#        [3600.],
#        [ 650.],
#        ...,
#        [1150.],
#        [1199.],
#        [9200.]])

# %%
y.shape
# Out:
# (260964, 1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
le1=LabelEncoder()
le2=LabelEncoder()
le3=LabelEncoder()
le4=LabelEncoder()

# %%
x
# Out:
# array([['kleinwagen', 'test', 18.0, ..., 6, 'benzin', 'nein'],
#        ['kleinwagen', 'test', 11.0, ..., 7, 'diesel', 'nein'],
#        ['limousine', 'test', 24.0, ..., 10, 'benzin', 'ja'],
#        ...,
#        ['bus', 'control', 19.0, ..., '3', 'benzin', 'nein'],
#        ['cabrio', 'test', 19.0, ..., '3', 'benzin', 'nein'],
#        ['bus', 'test', 23.0, ..., '3', 'diesel', 'nein']], dtype=object)

# %%
x[:,0]=le.fit_transform(x[:,0])

# %%
x[:,1]=le1.fit_transform(x[:,1])

# %%
x[:,3]=le2.fit_transform(x[:,3])

# %%
x[:,7]=le3.fit_transform(x[:,7])

# %%
x[:,8]=le4.fit_transform(x[:,8])

# %%
x
# Out:
# array([[4, 1, 18.0, ..., 6, 1, 1],
#        [4, 1, 11.0, ..., 7, 3, 1],
#        [6, 1, 24.0, ..., 10, 1, 0],
#        ...,
#        [1, 0, 19.0, ..., '3', 1, 1],
#        [2, 1, 19.0, ..., '3', 1, 1],
#        [1, 1, 23.0, ..., '3', 3, 1]], dtype=object)

# %%
x.shape
# Out:
# (260964, 9)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
oh=OneHotEncoder()
oh1=OneHotEncoder()

# %%
oh = OneHotEncoder(categorical_features=[0])
x = oh.fit_transform(x).toarray()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:390: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %%
x.shape
# Out:
# (260964, 16)

# %%
x=x[:,1:]

# %%
x.shape
# Out:
# (260964, 15)

# %%
oh1 = OneHotEncoder(categorical_features=[13])
x = oh1.fit_transform(x).toarray()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:390: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %%
x.shape
# Out:
# (260964, 21)

# %%
x=x[:,1:]

# %%
x.shape
# Out:
# (260964, 20)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=0)

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model=Sequential()

# %%
model.add(Dense(input_dim=20,init="random_uniform",output_dim=20,activation="relu"))
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=20, activation="relu", units=20, kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.add(Dense(init="random_uniform",output_dim=15))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=15, kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.add(Dense(init="random_uniform",output_dim=5))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=5, kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.add(Dense(init="random_uniform",output_dim=1))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1, kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.compile(optimizer='adam',loss='mean_squared_error',metrics=['mse'])

# %%
model.fit(x_train,y_train,epochs=50,batch_size=8)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 208771/208771 [==============================] - 68s 328us/step - loss: 146730804833.6055 - mean_squared_error: 146730804833.6055
# Epoch 2/50
# 208771/208771 [==============================] - 58s 276us/step - loss: 146720113635.2120 - mean_squared_error: 146720113635.2120
# Epoch 3/50
# 208771/208771 [==============================] - 66s 315us/step - loss: 146717436078.5419 - mean_squared_error: 146717436078.5419
# Epoch 4/50
# 208771/208771 [==============================] - 68s 327us/step - loss: 146709678243.9193 - mean_squared_error: 146709678243.9193
# Epoch 5/50
# 208771/208771 [==============================] - 60s 289us/step - loss: 146705732970.5549 - mean_squared_error: 146705732970.5549
# ...

# %%
model.save("project_class.h5")

# %%
y_train.shape
# Out:
# (208771, 1)

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([[ 730.5676],
#        [4821.1636],
#        [2246.0315],
#        ...,
#        [-232.0505],
#        [2877.1428],
#        [5676.4917]], dtype=float32)

# %%
y_test
# Out:
# array([[1295.],
#        [3100.],
#        [1800.],
#        ...,
#        [1750.],
#        [2200.],
#        [5150.]])

# %%
y_pred
# Out:
# array([[ 730.5676],
#        [4821.1636],
#        [2246.0315],
#        ...,
#        [-232.0505],
#        [2877.1428],
#        [5676.4917]], dtype=float32)

# %%
y_pred[9]
# Out:
# array([3206.1028], dtype=float32)

# %%
y_test[9]
# Out:
# array([2199.])

# %%
y_pred[7000]
# Out:
# array([5962.762], dtype=float32)

# %%
y_test[7000]
# Out:
# array([3850.])

# %%
y_test[100]
# Out:
# array([5099.])

# %%
y_pred[100]
# Out:
# array([6531.0386], dtype=float32)

# %%
y_pred[10000]
# Out:
# array([2880.305], dtype=float32)

# %%
y_test[10000]
# Out:
# array([1050.])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)*100
# Out:
# 1.0951906152056545

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 2455187741.6740904

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 3815.6068060880075
